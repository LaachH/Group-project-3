# %%
import numpy as np 
import pandas as pd 
import os
from plotly.offline import init_notebook_mode, iplot
import plotly as py
import plotly.figure_factory as FF

from plotly import tools
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
import datetime

from pathlib import Path
warnings.filterwarnings("ignore")
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
melb_stats = Path("MELBOURNE_HOUSE_PRICES_LESS.csv")
melb_stats2 = pd.read_csv(melb_stats, index_col="Date", parse_dates=True, infer_datetime_format=True)

# %%
melb_stats2
# Out:
#                       Suburb           Address  Rooms Type      Price Method  \
# Date
# 2017-01-04        Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 2017-01-04        Abbotsford     59A Turner St      3    h  1220000.0      S
# 2017-01-04        Abbotsford     119B Yarra St      3    h  1420000.0      S
# 2017-01-04        Aberfeldie        68 Vida St      3    h  1515000.0      S
# 2017-01-04      Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                      ...               ...    ...  ...        ...    ...
# 2018-03-31     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 2018-03-31     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 2018-03-31     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# 2018-03-31        Thomastown    3/1 Travers St      3    u        NaN     PI
# 2018-03-31  Williams Landing       1 Diadem Wy      4    h        NaN     SP
#
# ...

# %%
# Create the sunburst chart

# %%
# Create a new DataFrame with the mean house values by neighbourhood per year

df_average_value = melb_stats2.groupby("Suburb").mean().sort_values("Price", ascending=False)
df_average_value["Price per room"] = df_average_value["Price"]/df_average_value["Rooms"]
df_average_value = df_average_value.sort_values("Price per room", ascending=False).head(30)

# %%
df_average_value["Price per room"].plot(kind="bar", figsize = (30,20), title = "MELBOURNE TOP 30 $/ROOM")
# Out:
# <AxesSubplot:title={'center':'MELBOURNE TOP 30 $/ROOM'}, xlabel='Suburb'>

# %%
df_average_value2 = melb_stats2.groupby("Suburb").mean().sort_values("Price", ascending=True)

df_average_value2
# Out:
#                     Rooms          Price  Postcode  Propertycount  Distance
# Suburb
# Darley           3.000000  380000.000000    3340.0         2992.0      37.5
# Kurunjang        3.486486  381785.714286    3337.0         3553.0      31.7
# Melton South     3.090909  396267.500000    3338.0         4718.0      29.8
# Cockatoo         3.500000  397000.000000    3781.0         1636.0      42.1
# Mount Dandenong  2.500000  405000.000000    3767.0          552.0      30.1
# ...                   ...            ...       ...            ...       ...
# Maddingley       3.000000            NaN    3340.0         1399.0      37.5
# Menzies Creek    4.000000            NaN    3159.0          342.0      32.6
# Toolern Vale     4.000000            NaN    3337.0          317.0      31.7
# Warburton        1.500000            NaN    3799.0         1191.0      64.1
# Yarrambat        5.000000            NaN    3091.0          577.0      23.4
#
# [380 rows x 5 columns]

# %%
df_average_value2["Price per room"] = df_average_value2["Price"]/df_average_value2["Rooms"]

df_average_value2
# Out:
#                     Rooms          Price  Postcode  Propertycount  Distance  \
# Suburb
# Darley           3.000000  380000.000000    3340.0         2992.0      37.5
# Kurunjang        3.486486  381785.714286    3337.0         3553.0      31.7
# Melton South     3.090909  396267.500000    3338.0         4718.0      29.8
# Cockatoo         3.500000  397000.000000    3781.0         1636.0      42.1
# Mount Dandenong  2.500000  405000.000000    3767.0          552.0      30.1
# ...                   ...            ...       ...            ...       ...
# Maddingley       3.000000            NaN    3340.0         1399.0      37.5
# Menzies Creek    4.000000            NaN    3159.0          342.0      32.6
# Toolern Vale     4.000000            NaN    3337.0          317.0      31.7
# Warburton        1.500000            NaN    3799.0         1191.0      64.1
# Yarrambat        5.000000            NaN    3091.0          577.0      23.4
#
#                  Price per room
# Suburb
# ...

# %%
df_average_value2 = df_average_value2.sort_values("Price per room", ascending=True).head(100)

# %%
df_average_value2 = df_average_value2.sort_values("Price per room", ascending=True).head(30)

# %%
df_average_value2["Price per room"].plot(kind="bar", figsize = (30,20), title = "MELBOURNE BOTTOM 30 $/ROOM")
# Out:
# <AxesSubplot:title={'center':'MELBOURNE BOTTOM 30 $/ROOM'}, xlabel='Suburb'>

# %%
melb_stats2
# Out:
#                       Suburb           Address  Rooms Type      Price Method  \
# Date
# 2017-01-04        Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 2017-01-04        Abbotsford     59A Turner St      3    h  1220000.0      S
# 2017-01-04        Abbotsford     119B Yarra St      3    h  1420000.0      S
# 2017-01-04        Aberfeldie        68 Vida St      3    h  1515000.0      S
# 2017-01-04      Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                      ...               ...    ...  ...        ...    ...
# 2018-03-31     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 2018-03-31     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 2018-03-31     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# 2018-03-31        Thomastown    3/1 Travers St      3    u        NaN     PI
# 2018-03-31  Williams Landing       1 Diadem Wy      4    h        NaN     SP
#
# ...
