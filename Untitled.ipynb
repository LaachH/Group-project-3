# %%
import numpy as np 
import pandas as pd 
import os
from plotly.offline import init_notebook_mode, iplot
import plotly as py
import plotly.figure_factory as FF

from plotly import tools
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
import datetime

from pathlib import Path
warnings.filterwarnings("ignore")
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
melb_stats = Path("MELBOURNE_HOUSE_PRICES_LESS.csv")
melb_stats2 = pd.read_csv(melb_stats, index_col="Date", parse_dates=True, infer_datetime_format=True)

# %%
melb_stats2
# Out:
#                       Suburb           Address  Rooms Type      Price Method  \
# Date
# 2017-01-04        Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 2017-01-04        Abbotsford     59A Turner St      3    h  1220000.0      S
# 2017-01-04        Abbotsford     119B Yarra St      3    h  1420000.0      S
# 2017-01-04        Aberfeldie        68 Vida St      3    h  1515000.0      S
# 2017-01-04      Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                      ...               ...    ...  ...        ...    ...
# 2018-03-31     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 2018-03-31     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 2018-03-31     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# 2018-03-31        Thomastown    3/1 Travers St      3    u        NaN     PI
# 2018-03-31  Williams Landing       1 Diadem Wy      4    h        NaN     SP
#
# ...

# %%
dt = datetime.datetime(2012, 1, 1,0,0)
dt.year
# Out:
# 2012

# %%
# Create a new DataFrame with the mean house values by neighbourhood per year
df_average_value = melb_stats2[["Suburb", "Price"]]
df_average_value = df_average_value.reset_index()
df_average_value.head(10)
# Out:
#         Date        Suburb      Price
# 0 2017-01-04    Abbotsford  1490000.0
# 1 2017-01-04    Abbotsford  1220000.0
# 2 2017-01-04    Abbotsford  1420000.0
# 3 2017-01-04    Aberfeldie  1515000.0
# 4 2017-01-04  Airport West   670000.0
# 5 2017-01-04  Airport West   530000.0
# 6 2017-01-04  Airport West   540000.0
# 7 2017-01-04  Airport West   715000.0
# 8 2017-01-04     Albanvale        NaN
# 9 2017-01-04   Albert Park  1925000.0

# %%
# Helper create_bar_chart function
def create_bar_chart(data, title, xlabel, ylabel, color):
    """
    Create a barplot based in the data argument.
    """
    
    fig = plt.figure()
    bar_chart = melb_stats2.plot.bar(color=color)
    bar_chart.set_xlabel(xlabel, fontsize = 10)
    bar_chart.set_ylabel(ylabel, fontsize = 10)
    bar_chart.set_title(title, fontsize = 12, fontweight = 'bold')
    plt.show()
    plt.Price(fig)

# %%
# Create a bar chart per year to show the number of dwelling types

# Bar chart for 2017
create_bar_chart(melb_stats2, "Me1bourne prices", "2017", "Dwelling Unit Type", "red")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1632/604614913.py in <module>
#       2
#       3 # Bar chart for 2017
# ----> 4 create_bar_chart(melb_stats2, "Me1bourne prices", "2017", "Dwelling Unit Type", "red")
#       5
#       6
#
# ~\AppData\Local\Temp/ipykernel_1632/3081567510.py in create_bar_chart(data, title, xlabel, ylabel, color)
#       6
#       7     fig = plt.figure()
# ----> 8     bar_chart = melb_stats2.plot.bar(color=color)
#       9     bar_chart.set_xlabel(xlabel, fontsize = 10)
#      10     bar_chart.set_ylabel(ylabel, fontsize = 10)
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1128         other axis represents a measured value.
#    1129         """
# -> 1130         return self(kind="bar", x=x, y=y, **kwargs)
#    1131
#    1132     @Appender(
#
# ...
